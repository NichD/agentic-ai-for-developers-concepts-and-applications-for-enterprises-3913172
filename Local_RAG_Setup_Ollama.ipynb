# %% [markdown]
# # LOCAL RAG SETUP WITH OLLAMA - JUPYTER NOTEBOOK WORKFLOW
#
# - This notebook transitions from Azure OpenAI to local Ollama deployment
# - **Target**: Python 3.11+ (3.12 recommended for best library support)
# - **Hardware**: Mac M3 Max (or better) with 64GB RAM (or better)

# %% [markdown]
# ## 1: Environment Setup and Validation

# %%
import sys
import subprocess
import os
from pathlib import Path

print("=== ENVIRONMENT VALIDATION ===")
print(f"Python version: {sys.version}")
print(f"Python executable: {sys.executable}")

# Check if we're in a virtual environment
def check_virtual_env():
    """Check if running in a virtual environment"""
    return (
        hasattr(sys, 'real_prefix') or  # virtualenv
        (hasattr(sys, 'base_prefix') and sys.base_prefix != sys.prefix) or  # venv
        'conda' in sys.executable.lower()  # conda
    )

in_venv = check_virtual_env()
print(f"In virtual environment: {in_venv}")

if not in_venv:
    print("\n⚠️  WARNING: Not in a virtual environment!")
    print("Recommended: Create a virtual environment for this project")
    print("Run in terminal:")
    print("  python3.12 -m venv local_rag_env")
    print("  source local_rag_env/bin/activate  # On Mac/Linux")
    print("  pip install jupyter")
    print("  jupyter notebook")
# Out:
# === ENVIRONMENT VALIDATION ===
# Python version: 3.12.10 (main, Apr  8 2025, 11:35:47) [Clang 17.0.0 (clang-1700.0.13.3)]
# Python executable: /Users/ndana/envs/local_rag_env/bin/python
# In virtual environment: True

# %% [markdown]
# ## 2: Install Required Dependencies
#
# **Note**: Run this cell only once, or when you need to update packages

# %%
install_packages = True  # Set to False after first run

if install_packages:
    print("=== INSTALLING DEPENDENCIES ===")
    
    # Core packages for local RAG
    packages = [
        "llama-index>=0.9.0",                   # Main RAG framework
        "llama-index-llms-ollama",              # Ollama LLM integration
        "llama-index-embeddings-ollama",        # Ollama embeddings (if available)
        "lama-index-llms-azure-openai",         # Azure OpenAI LLM integration
        "llama-index-embeddings-azure-openai",  # Azure OpenAI embeddings
        "llama-index-embeddings-huggingface",   # Hugging Face embeddings
        "sentence-transformers",                # Local embedding models
        "chromadb",                             # Vector database
        "pypdf",                                # PDF processing
        "requests",                             # HTTP client for Ollama API
        "numpy",                                # Numerical operations
        "pandas",                               # Data manipulation
        "tqdm",                                 # Progress bars
        "python-dotenv",                        # Environment variables
    ]                
    
    for package in packages:
        try:
            print(f"Installing {package}...")
            subprocess.check_call([sys.executable, "-m", "pip", "install", package])
        except subprocess.CalledProcessError as e:
            print(f"❌ Failed to install {package}: {e}")
    
    print("✅ Package installation complete!")
else:
    print("Skipping package installation (set install_packages=True to reinstall)")
# Out:
# === INSTALLING DEPENDENCIES ===
# Installing llama-index>=0.9.0...
# Requirement already satisfied: llama-index>=0.9.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (0.12.37)
# Requirement already satisfied: llama-index-agent-openai<0.5,>=0.4.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index>=0.9.0) (0.4.8)
# Requirement already satisfied: llama-index-cli<0.5,>=0.4.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index>=0.9.0) (0.4.1)
# Requirement already satisfied: llama-index-core<0.13,>=0.12.36 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index>=0.9.0) (0.12.37)
# Requirement already satisfied: llama-index-embeddings-openai<0.4,>=0.3.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index>=0.9.0) (0.3.1)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index>=0.9.0) (0.6.11)
# Requirement already satisfied: llama-index-llms-openai<0.4,>=0.3.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index>=0.9.0) (0.3.44)
# Requirement already satisfied: llama-index-multi-modal-llms-openai<0.5,>=0.4.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index>=0.9.0) (0.4.3)
# Requirement already satisfied: llama-index-program-openai<0.4,>=0.3.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index>=0.9.0) (0.3.1)
# Requirement already satisfied: llama-index-question-gen-openai<0.4,>=0.3.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index>=0.9.0) (0.3.0)
# Requirement already satisfied: llama-index-readers-file<0.5,>=0.4.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index>=0.9.0) (0.4.7)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index>=0.9.0) (0.4.0)
# Requirement already satisfied: nltk>3.8.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index>=0.9.0) (3.9.1)
# Requirement already satisfied: openai>=1.14.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-agent-openai<0.5,>=0.4.0->llama-index>=0.9.0) (1.82.0)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (3.12.0)
# Requirement already satisfied: aiosqlite in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (0.21.0)
# Requirement already satisfied: banks<3,>=2.0.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (2.1.2)
# Requirement already satisfied: dataclasses-json in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (2025.5.1)
# Requirement already satisfied: httpx in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (0.28.1)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (3.4.2)
# Requirement already satisfied: numpy in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (2.2.6)
# Requirement already satisfied: pillow>=9.0.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (11.2.1)
# Requirement already satisfied: pydantic>=2.8.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (2.11.5)
# Requirement already satisfied: pyyaml>=6.0.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (6.0.2)
# Requirement already satisfied: requests>=2.31.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (2.32.3)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (2.0.41)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (9.1.2)
# Requirement already satisfied: tiktoken>=0.7.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (0.9.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (4.13.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (0.9.0)
# Requirement already satisfied: wrapt in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (1.20.0)
# Requirement already satisfied: griffe in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (1.7.3)
# Requirement already satisfied: jinja2 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (3.1.6)
# Requirement already satisfied: platformdirs in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (4.3.8)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.12.3 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index>=0.9.0) (4.13.4)
# Requirement already satisfied: pandas in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index>=0.9.0) (2.2.3)
# Requirement already satisfied: pypdf<6.0.0,>=5.1.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index>=0.9.0) (5.5.0)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index>=0.9.0) (0.0.26)
# Requirement already satisfied: soupsieve>1.2 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from beautifulsoup4<5.0.0,>=4.12.3->llama-index-readers-file<0.5,>=0.4.0->llama-index>=0.9.0) (2.7)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index>=0.9.0) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index>=0.9.0) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index>=0.9.0) (0.10.0)
# Requirement already satisfied: sniffio in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index>=0.9.0) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index>=0.9.0) (3.10)
# Requirement already satisfied: certifi in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from httpx->llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from httpx->llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (0.4.1)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: llama-cloud<0.2.0,>=0.1.13 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index>=0.9.0) (0.1.22)
# Requirement already satisfied: llama-parse>=0.5.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-readers-llama-parse>=0.4.0->llama-index>=0.9.0) (0.6.23)
# Requirement already satisfied: llama-cloud-services>=0.6.23 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index>=0.9.0) (0.6.23)
# Requirement already satisfied: click<9.0.0,>=8.1.7 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-cloud-services>=0.6.23->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index>=0.9.0) (8.1.8)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-cloud-services>=0.6.23->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index>=0.9.0) (1.1.0)
# Requirement already satisfied: joblib in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from nltk>3.8.1->llama-index>=0.9.0) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from nltk>3.8.1->llama-index>=0.9.0) (2024.11.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (2.4.0)
# Requirement already satisfied: greenlet>=1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (3.2.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from dataclasses-json->llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (3.26.1)
# Requirement already satisfied: packaging>=17.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (25.0)
# Requirement already satisfied: colorama>=0.4 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from griffe->banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from jinja2->banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.36->llama-index>=0.9.0) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from pandas->llama-index-readers-file<0.5,>=0.4.0->llama-index>=0.9.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from pandas->llama-index-readers-file<0.5,>=0.4.0->llama-index>=0.9.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from pandas->llama-index-readers-file<0.5,>=0.4.0->llama-index>=0.9.0) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-readers-file<0.5,>=0.4.0->llama-index>=0.9.0) (1.17.0)
# Installing llama-index-llms-ollama...
# Requirement already satisfied: llama-index-llms-ollama in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (0.5.6)
# Requirement already satisfied: llama-index-core<0.13,>=0.12.4 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-llms-ollama) (0.12.37)
# Requirement already satisfied: ollama>=0.4.3 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-llms-ollama) (0.4.8)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (3.12.0)
# Requirement already satisfied: aiosqlite in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (0.21.0)
# Requirement already satisfied: banks<3,>=2.0.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (2.1.2)
# Requirement already satisfied: dataclasses-json in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (2025.5.1)
# Requirement already satisfied: httpx in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (0.28.1)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (3.9.1)
# Requirement already satisfied: numpy in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (2.2.6)
# Requirement already satisfied: pillow>=9.0.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (11.2.1)
# Requirement already satisfied: pydantic>=2.8.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (2.11.5)
# Requirement already satisfied: pyyaml>=6.0.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (6.0.2)
# Requirement already satisfied: requests>=2.31.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (2.32.3)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (2.0.41)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (9.1.2)
# Requirement already satisfied: tiktoken>=0.7.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (0.9.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (4.13.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (0.9.0)
# Requirement already satisfied: wrapt in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (1.20.0)
# Requirement already satisfied: griffe in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (1.7.3)
# Requirement already satisfied: jinja2 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (3.1.6)
# Requirement already satisfied: platformdirs in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (4.3.8)
# Requirement already satisfied: idna>=2.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (3.10)
# Requirement already satisfied: click in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (8.1.8)
# Requirement already satisfied: joblib in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (2024.11.6)
# Requirement already satisfied: anyio in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from httpx->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (4.9.0)
# Requirement already satisfied: certifi in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from httpx->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from httpx->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (2.4.0)
# Requirement already satisfied: greenlet>=1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (3.2.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from anyio->httpx->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (1.3.1)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from dataclasses-json->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (3.26.1)
# Requirement already satisfied: packaging>=17.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (25.0)
# Requirement already satisfied: colorama>=0.4 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from griffe->banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from jinja2->banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.4->llama-index-llms-ollama) (3.0.2)
# Installing llama-index-embeddings-ollama...
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: llama-index-embeddings-ollama in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (0.6.0)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-embeddings-ollama) (0.12.37)
# Requirement already satisfied: ollama>=0.3.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-embeddings-ollama) (0.4.8)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (3.12.0)
# Requirement already satisfied: aiosqlite in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (0.21.0)
# Requirement already satisfied: banks<3,>=2.0.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (2.1.2)
# Requirement already satisfied: dataclasses-json in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (2025.5.1)
# Requirement already satisfied: httpx in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (0.28.1)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (3.9.1)
# Requirement already satisfied: numpy in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (2.2.6)
# Requirement already satisfied: pillow>=9.0.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (11.2.1)
# Requirement already satisfied: pydantic>=2.8.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (2.11.5)
# Requirement already satisfied: pyyaml>=6.0.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (6.0.2)
# Requirement already satisfied: requests>=2.31.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (2.32.3)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (2.0.41)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (9.1.2)
# Requirement already satisfied: tiktoken>=0.7.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (0.9.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (4.13.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (0.9.0)
# Requirement already satisfied: wrapt in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (1.20.0)
# Requirement already satisfied: griffe in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from banks<3,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (1.7.3)
# Requirement already satisfied: jinja2 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from banks<3,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (3.1.6)
# Requirement already satisfied: platformdirs in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from banks<3,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (4.3.8)
# Requirement already satisfied: idna>=2.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (3.10)
# Requirement already satisfied: click in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (8.1.8)
# Requirement already satisfied: joblib in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (2024.11.6)
# Requirement already satisfied: anyio in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (4.9.0)
# Requirement already satisfied: certifi in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (2.4.0)
# Requirement already satisfied: greenlet>=1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (3.2.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from anyio->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (3.26.1)
# Requirement already satisfied: packaging>=17.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (25.0)
# Requirement already satisfied: colorama>=0.4 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from griffe->banks<3,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from jinja2->banks<3,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-embeddings-ollama) (3.0.2)
# Installing lama-index-llms-azure-openai...
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ERROR: Could not find a version that satisfies the requirement lama-index-llms-azure-openai (from versions: none)
# ERROR: No matching distribution found for lama-index-llms-azure-openai
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ❌ Failed to install lama-index-llms-azure-openai: Command '['/Users/ndana/envs/local_rag_env/bin/python', '-m', 'pip', 'install', 'lama-index-llms-azure-openai']' returned non-zero exit status 1.
# Installing llama-index-embeddings-azure-openai...
# Requirement already satisfied: llama-index-embeddings-azure-openai in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (0.3.5)
# Requirement already satisfied: llama-index-core<0.13,>=0.12.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-embeddings-azure-openai) (0.12.37)
# Requirement already satisfied: llama-index-embeddings-openai<0.4,>=0.3.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-embeddings-azure-openai) (0.3.1)
# Requirement already satisfied: llama-index-llms-azure-openai<0.4,>=0.3.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-embeddings-azure-openai) (0.3.2)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (3.12.0)
# Requirement already satisfied: aiosqlite in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (0.21.0)
# Requirement already satisfied: banks<3,>=2.0.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (2.1.2)
# Requirement already satisfied: dataclasses-json in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (2025.5.1)
# Requirement already satisfied: httpx in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (0.28.1)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (3.9.1)
# Requirement already satisfied: numpy in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (2.2.6)
# Requirement already satisfied: pillow>=9.0.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (11.2.1)
# Requirement already satisfied: pydantic>=2.8.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (2.11.5)
# Requirement already satisfied: pyyaml>=6.0.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (6.0.2)
# Requirement already satisfied: requests>=2.31.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (2.32.3)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (2.0.41)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (9.1.2)
# Requirement already satisfied: tiktoken>=0.7.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (0.9.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (4.13.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (0.9.0)
# Requirement already satisfied: wrapt in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (1.17.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (1.20.0)
# Requirement already satisfied: griffe in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (1.7.3)
# Requirement already satisfied: jinja2 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (3.1.6)
# Requirement already satisfied: platformdirs in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.0->llama-index-embeddings-azure-openai) (4.3.8)
# Requirement already satisfied: openai>=1.1.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-embeddings-openai<0.4,>=0.3.0->llama-index-embeddings-azure-openai) (1.82.0)
# Requirement already satisfied: azure-identity<2.0.0,>=1.15.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from llama-index-llms-azure-openai<0.4,>=0.3.0->llama-index-embeddings-azure-openai) (1.23.0)
# ...
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from chromadb) (32.0.1)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from chromadb) (9.1.2)
# Requirement already satisfied: pyyaml>=6.0.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from chromadb) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from chromadb) (3.10.18)
# Requirement already satisfied: httpx>=0.27.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from chromadb) (14.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from chromadb) (4.23.0)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from fastapi==0.115.9->chromadb) (0.45.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from pydantic>=1.9->chromadb) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from pydantic>=1.9->chromadb) (0.4.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from starlette<0.46.0,>=0.40.0->fastapi==0.115.9->chromadb) (4.9.0)
# Requirement already satisfied: idna>=2.8 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette<0.46.0,>=0.40.0->fastapi==0.115.9->chromadb) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette<0.46.0,>=0.40.0->fastapi==0.115.9->chromadb) (1.3.1)
# Requirement already satisfied: packaging>=19.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from build>=1.0.3->chromadb) (25.0)
# Requirement already satisfied: pyproject_hooks in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: certifi in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from httpx>=0.27.0->chromadb) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.16.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from jsonschema>=4.19.0->chromadb) (0.25.1)
# Requirement already satisfied: six>=1.9.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (2.40.2)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Requirement already satisfied: requests-oauthlib in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (2.4.0)
# Requirement already satisfied: durationpy>=0.7 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: coloredlogs in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (25.2.10)
# Requirement already satisfied: protobuf in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.4)
# Requirement already satisfied: sympy in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.6.1)
# Requirement already satisfied: zipp>=3.20 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.2.0->chromadb) (1.17.2)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.70.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.33.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.33.1)
# Requirement already satisfied: opentelemetry-proto==1.33.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.33.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.54b1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.54b1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.54b1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: opentelemetry-util-http==0.54b1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.54b1)
# Requirement already satisfied: asgiref~=3.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from opentelemetry-instrumentation-asgi==0.54b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: backoff>=1.10.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from posthog>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from tokenizers>=0.13.2->chromadb) (0.32.0)
# Requirement already satisfied: filelock in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.5.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.1.2)
# Requirement already satisfied: click<8.2,>=8.0.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.5)
# Requirement already satisfied: websockets>=10.4 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Installing pypdf...
# Requirement already satisfied: pypdf in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (5.5.0)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Installing requests...
# Requirement already satisfied: requests in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from requests) (2025.4.26)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Installing numpy...
# Requirement already satisfied: numpy in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (2.2.6)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Installing pandas...
# Requirement already satisfied: pandas in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Installing tqdm...
# Requirement already satisfied: tqdm in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (4.67.1)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Installing python-dotenv...
# Requirement already satisfied: python-dotenv in /Users/ndana/envs/local_rag_env/lib/python3.12/site-packages (1.1.0)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ✅ Package installation complete!

# %% [markdown]
# ## 3: Ollama Setup and Model Management

# %%
import requests
import json

print("=== OLLAMA SETUP AND VALIDATION ===")

# Check if Ollama is running
def check_ollama_status():
    """Check if Ollama service is running"""
    try:
        response = requests.get("http://localhost:11434/api/version", timeout=5)
        if response.status_code == 200:
            version_info = response.json()
            print(f"✅ Ollama is running - Version: {version_info.get('version', 'unknown')}")
            return True
    except requests.exceptions.RequestException:
        pass
    
    print("❌ Ollama is not running")
    print("Please start Ollama:")
    print("  - Open terminal and run: ollama serve")
    print("  - Or start Ollama app from Applications")
    return False

ollama_running = check_ollama_status()

# List available models
def list_ollama_models():
    """List currently pulled Ollama models"""
    try:
        response = requests.get("http://localhost:11434/api/tags")
        if response.status_code == 200:
            models = response.json().get('models', [])
            print(f"\n📋 Available Ollama models ({len(models)} total):")
            for model in models:
                name = model['name']
                size = model.get('size', 0) / (1024**3)  # Convert to GB
                modified = model.get('modified_at', '')[:10]  # Date only
                print(f"  • {name:<25} | {size:.1f}GB | {modified}")
            return [model['name'] for model in models]
        else:
            print("Failed to fetch model list")
            return []
    except requests.exceptions.RequestException as e:
        print(f"Error fetching models: {e}")
        return []

available_models = list_ollama_models() if ollama_running else []

# Recommended models for your hardware
recommended_models = {
    "mistral:7b-instruct": "Mistral 7B - Excellent general purpose model (~4GB)",
    "mixtral:8x7b": "Mixtral 8x7B - Very capable, mixture of experts (~26GB)", 
    # "llama3:8b-instruct": "Llama 3 8B - Latest Meta model (~4.7GB)",
    # "codellama:13b-instruct": "Code Llama 13B - Code-focused (~7GB)",
    "nomic-embed-text:latest": "Nomic Embed - Local embedding model (~274MB)"
}

print(f"\n🎯 RECOMMENDED MODELS FOR YOUR HARDWARE (64GB RAM):")
for model, description in recommended_models.items():
    status = "✅ Available" if model in available_models else "⬇️  Pull needed"
    print(f"  {model:<25} | {description} | {status}")
# Out:
# === OLLAMA SETUP AND VALIDATION ===
# ✅ Ollama is running - Version: 0.7.1
#
# 📋 Available Ollama models (30 total):
#   • nomic-embed-text:latest   | 0.3GB | 2025-05-25
#   • mistral:7b-instruct       | 3.8GB | 2025-05-25
#   • deepseek-r1:70b           | 39.6GB | 2025-05-07
#   • qwen3:30b                 | 17.3GB | 2025-05-07
#   • phi4-reasoning:plus       | 10.4GB | 2025-05-07
#   • llama3.3:70b              | 39.6GB | 2025-05-07
#   • qwen3:32b                 | 18.8GB | 2025-05-07
#   • gemma3:27b                | 16.2GB | 2025-04-19
#   • gemma3:12b                | 7.6GB | 2025-04-19
#   • llama3.2:3b               | 1.9GB | 2025-04-19
#   • granite-code:20b          | 10.8GB | 2025-04-19
#   • starcoder2:7b             | 3.8GB | 2025-04-19
#   • granite-code:8b           | 4.3GB | 2025-04-19
#   • starcoder2:latest         | 1.6GB | 2025-04-19
#   • granite3.2-vision:latest  | 2.3GB | 2025-04-19
#   • granite3.1-moe:latest     | 1.9GB | 2025-04-19
#   • granite3.2:8b             | 4.6GB | 2025-04-19
#   • mixtral:8x7b              | 24.6GB | 2025-04-19
#   • qwq:latest                | 18.5GB | 2025-04-19
#   • r1-1776:70b               | 39.6GB | 2025-04-19
#   • deepseek-r1:8b            | 4.6GB | 2025-04-19
#   • deepseek-llm:7b           | 3.7GB | 2025-04-19
#   • gemma2:9b                 | 5.1GB | 2025-04-19
#   • cogito:8b                 | 4.6GB | 2025-04-19
#   • qwen2.5-coder:7b          | 4.4GB | 2025-04-19
#   • qwen2.5:7b                | 4.4GB | 2025-04-19
#   • phi4:latest               | 8.4GB | 2025-04-19
#   • phi4-mini:latest          | 2.3GB | 2025-04-19
#   • llama3.1:latest           | 4.6GB | 2025-04-19
#   • mistral:7b                | 3.8GB | 2025-04-19
#
# 🎯 RECOMMENDED MODELS FOR YOUR HARDWARE (64GB RAM):
#   mistral:7b-instruct       | Mistral 7B - Excellent general purpose model (~4GB) | ✅ Available
#   mixtral:8x7b              | Mixtral 8x7B - Very capable, mixture of experts (~26GB) | ✅ Available
#   nomic-embed-text:latest   | Nomic Embed - Local embedding model (~274MB) | ✅ Available

# %% [markdown]
# ## 4: Pull Recommended Models (if needed)
#
# **NOTE**: Only run this cell if you need to pull new models

# %%
pull_models = False  # Set to True to pull missing models

if pull_models and ollama_running:
    print("=== PULLING RECOMMENDED MODELS ===")
    
    # Start with smaller models first
    models_to_pull = [
        "nomic-embed-text:latest",      # Embedding model first
        "mistral:7b-instruct",   # Small but capable LLM
        "mixtral:8x7b", # Uncomment for larger, more capable model
    ]
    
    for model in models_to_pull:
        if model not in available_models:
            print(f"\n📥 Pulling {model}...")
            print("This may take several minutes depending on model size...")
            
            # Use subprocess to show real-time progress
            try:
                result = subprocess.run(
                    ["ollama", "pull", model],
                    capture_output=False,  # Show output in real-time
                    text=True,
                    timeout=1800  # 30 minute timeout
                )
                if result.returncode == 0:
                    print(f"✅ Successfully pulled {model}")
                else:
                    print(f"❌ Failed to pull {model}")
            except subprocess.TimeoutExpired:
                print(f"⏰ Timeout pulling {model} - this may indicate a slow connection")
            except FileNotFoundError:
                print("❌ Ollama CLI not found. Please install Ollama first.")
                break
        else:
            print(f"✅ {model} already available")
    
    # Refresh model list
    available_models = list_ollama_models()
else:
    print("Skipping model pull (set pull_models=True to pull missing models)")
# Out:
# Skipping model pull (set pull_models=True to pull missing models)

# %% [markdown]
# ## 5: Test Local Model Connections

# %%
from llama_index.llms.ollama import Ollama
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
import traceback

print("=== TESTING LOCAL MODEL CONNECTIONS ===")

# Test LLM connection
target_model = "mixtral:8x7b"  # Default model for testing
def test_local_llm(model_name=target_model):
    """Test local LLM connection and response"""
    print(f"\n🧠 Testing LLM: {model_name}")
    
    if model_name not in available_models:
        print(f"❌ Model {model_name} not available. Available models: {available_models}")
        return None
    
    try:
        # Initialize Ollama LLM
        llm = Ollama(
            model=model_name,
            base_url="http://localhost:11434",
            request_timeout=60.0,
        )
        
        # Test with a simple prompt
        test_prompt = "Explain what RAG (Retrieval-Augmented Generation) is in one sentence."
        print(f"Prompt: {test_prompt}")
        
        response = llm.complete(test_prompt)
        print(f"Response: {response.text.strip()}")
        print("✅ LLM test successful!")
        return llm
        
    except Exception as e:
        print(f"❌ LLM test failed: {e}")
        traceback.print_exc()
        return None

# Test embedding model
def test_local_embeddings():
    """Test local embedding model"""
    print(f"\n🔢 Testing Embedding Model")
    
    try:
        # Use HuggingFace sentence transformers (runs locally)
        # This is more reliable than Ollama embeddings which may not be available
        embed_model = HuggingFaceEmbedding(
            model_name="sentence-transformers/all-MiniLM-L6-v2",  # Small, fast model
            max_length=512,
        )
        
        # Test embedding
        test_texts = [
            "This is a test document about machine learning.",
            "RAG systems combine retrieval with generation.",
            "Local models run on your own hardware."
        ]
        
        print("Testing embeddings for sample texts...")
        embeddings = []
        for text in test_texts:
            emb = embed_model.get_text_embedding(text)
            embeddings.append(emb)
            print(f"  '{text[:30]}...' -> {len(emb)} dimensions")
        
        # Test similarity
        import numpy as np
        def cosine_similarity(a, b):
            return np.dot(a, b) / (np.linalg.norm(a) * np.linalg.norm(b))
        
        sim1 = cosine_similarity(embeddings[0], embeddings[1])
        sim2 = cosine_similarity(embeddings[0], embeddings[2])
        
        print(f"Similarity (ML vs RAG): {sim1:.3f}")
        print(f"Similarity (ML vs Local): {sim2:.3f}")
        print("✅ Embedding test successful!")
        return embed_model
        
    except Exception as e:
        print(f"❌ Embedding test failed: {e}")
        traceback.print_exc()
        return None

# Run tests
local_llm = test_local_llm()
local_embeddings = test_local_embeddings()
# Out:
# === TESTING LOCAL MODEL CONNECTIONS ===
#
# 🧠 Testing LLM: mixtral:8x7b
# Prompt: Explain what RAG (Retrieval-Augmented Generation) is in one sentence.
# Response: lexiafriendly RAG, or Retrieval-Augmented Generation, is a method that combines using an initialized model with retrieving relevant information from external sources to enhance the generation of responses.
# ✅ LLM test successful!
#
# 🔢 Testing Embedding Model
# Testing embeddings for sample texts...
#   'This is a test document about ...' -> 384 dimensions
#   'RAG systems combine retrieval ...' -> 384 dimensions
#   'Local models run on your own h...' -> 384 dimensions
# Similarity (ML vs RAG): 0.204
# Similarity (ML vs Local): 0.087
# ✅ Embedding test successful!

# %% [markdown]
# ## 6: Create Local RAG Configuration

# %%
from llama_index.core import Settings
from llama_index.core.node_parser import SentenceSplitter

print("=== CONFIGURING LOCAL RAG SYSTEM ===")

if local_llm and local_embeddings:
    # Configure LlamaIndex global settings
    Settings.llm = local_llm
    Settings.embed_model = local_embeddings
    
    # Configure text splitter (improved chunking based on your previous work)
    Settings.node_parser = SentenceSplitter(
        chunk_size=800,      # Similar to your max_chars
        chunk_overlap=100,   # Overlap for context preservation
        paragraph_separator="\n\n",  # Better paragraph detection
        secondary_chunking_regex="[^,.;。]+[,.;。]?",  # Sentence-level backup
    )
    
    print("✅ Local RAG configuration complete!")
    print(f"LLM Model: {local_llm.model}")
    print(f"Embedding Model: {local_embeddings.model_name}")
    print(f"Chunk Size: {Settings.node_parser.chunk_size}")
    print(f"Chunk Overlap: {Settings.node_parser.chunk_overlap}")
    
    # Test the complete pipeline with more comprehensive examples
    print("\n🔄 Testing Complete Pipeline...")
    from llama_index.core import VectorStoreIndex, Document
    
    # Create test documents that mirror your use case
    test_docs = [
        Document(text="""
        Aeroflow Technical Specifications:
        The Aeroflow system features advanced aerodynamic design principles that optimize fuel efficiency 
        and reduce environmental impact. The propulsion system incorporates cutting-edge technology 
        with hybrid-electric capabilities. Maintenance intervals are scheduled every 500 operational hours 
        or 6 months, whichever comes first. The comprehensive warranty covers all major components 
        for 24 months from delivery date.
        """),
        Document(text="""
        EcoSprint Performance Features:
        EcoSprint represents the next generation of eco-friendly transportation technology. 
        The system utilizes regenerative energy capture and advanced battery management systems. 
        Low maintenance requirements include basic inspections every 1000 hours of operation. 
        Environmental certifications include ISO 14001 compliance. Extended warranty coverage 
        provides 36 months of comprehensive protection for all electronic and mechanical systems.
        """),
        Document(text="""
        Retrieval-Augmented Generation Implementation:
        RAG systems combine large language models with external knowledge retrieval mechanisms. 
        This approach significantly reduces hallucination rates while improving response accuracy. 
        Local deployment offers privacy benefits and eliminates dependency on cloud services. 
        Chunking strategies are critical for optimal performance, with typical sizes ranging 
        from 500-1000 characters depending on content type.
        """),
    ]
    
    # Create vector index with performance monitoring
    try:
        print("Creating vector index from test documents...")
        index = VectorStoreIndex.from_documents(
            test_docs,
            embed_model=local_embeddings,
            show_progress=True
        )
        
        # Create query engine with custom settings
        query_engine = index.as_query_engine(
            llm=local_llm,
            similarity_top_k=3,  # Retrieve top 3 most relevant chunks
            response_mode="compact"  # Efficient response generation
        )
        
        # Test multiple queries to validate different scenarios
        test_queries = [
            "What are the maintenance requirements for Aeroflow?",
            "Compare the warranty periods for both products.",
            "What are the benefits of local RAG deployment?",
            "How does EcoSprint handle environmental compliance?"
        ]
        
        for i, query in enumerate(test_queries, 1):
            print(f"\n--- Test Query {i} ---")
            print(f"Query: {query}")
            
            try:
                response = query_engine.query(query)
                print(f"Response: {response.response}")
                
                # Show source information if available
                if hasattr(response, 'source_nodes') and response.source_nodes:
                    print(f"Sources used: {len(response.source_nodes)} chunks")
                
            except Exception as e:
                print(f"❌ Query failed: {e}")
        
        print("\n✅ Complete RAG pipeline test successful!")
        
        # Store for use in later cells
        global test_query_engine, test_index
        test_query_engine = query_engine
        test_index = index
        
    except Exception as e:
        print(f"❌ Pipeline test failed: {e}")
        traceback.print_exc()
        
else:
    print("❌ Cannot configure RAG system - LLM or embedding model initialization failed")
# Out:
# === CONFIGURING LOCAL RAG SYSTEM ===
# ✅ Local RAG configuration complete!
# LLM Model: mixtral:8x7b
# Embedding Model: sentence-transformers/all-MiniLM-L6-v2
# Chunk Size: 800
# Chunk Overlap: 100
#
# 🔄 Testing Complete Pipeline...
# Creating vector index from test documents...
# Parsing nodes:   0%|          | 0/3 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/3 [00:00<?, ?it/s]
# --- Test Query 1 ---
# Query: What are the maintenance requirements for Aeroflow?
# Response:  The Aeroflow system has scheduled maintenance intervals every 500 operational hours or 6 months, whichever comes first. The comprehensive warranty covers all major components for 24 months from the delivery date.
# Sources used: 3 chunks
#
# --- Test Query 2 ---
# Query: Compare the warranty periods for both products.
# Response:  The EcoSprint provides 36 months of comprehensive protection for all electronic and mechanical systems, while the Aeroflow offers a warranty coverage of 24 months from the delivery date for all major components. Therefore, the EcoSprint has a longer warranty period compared to the Aeroflow.
# Sources used: 3 chunks
#
# --- Test Query 3 ---
# Query: What are the benefits of local RAG deployment?
# Response:  Benefits of local Retrieval-Augmented Generation (RAG) system deployment include privacy advantages as sensitive data is processed and stored locally without the need for cloud services. Additionally, local deployment eliminates dependency on external networks or systems, ensuring consistent performance and reducing response time. Lastly, it offers improved control over system updates and configurations.
# Sources used: 3 chunks
#
# --- Test Query 4 ---
# Query: How does EcoSprint handle environmental compliance?
# Response:  EcoSprint manages environmental compliance through the use of ISO 140
# Sources used: 3 chunks
#
# ✅ Complete RAG pipeline test successful!

# %% [markdown]
# ## 7: Migration Helper Fcns - Azure to Local

# %%
print("=== MIGRATION HELPER FUNCTIONS ===")

def create_local_rag_components(llm_model="mixtral:8x7b", embedding_model="sentence-transformers/all-MiniLM-L6-v2"):
    """Create local equivalents of your Azure components with optimized settings"""
    
    components = {}
    
    # LLM (replaces AzureOpenAI)
    components['llm'] = Ollama(
        model=llm_model,
        base_url="http://localhost:11434",
        request_timeout=120.0,
        # Additional parameters for better performance
        temperature=0.1,  # Lower temperature for more consistent responses
        num_predict=512,  # Limit response length for efficiency
    )
    
    # Embedding Model (replaces AzureOpenAIEmbedding) 
    components['embed_model'] = HuggingFaceEmbedding(
        model_name=embedding_model,
        max_length=512,
        normalize=True,  # Normalize embeddings for better similarity calculation
    )
    
    # Enhanced Text Splitter (replaces your chunking function)
    components['text_splitter'] = SentenceSplitter(
        chunk_size=800,
        chunk_overlap=100,
        paragraph_separator="\n\n",
        secondary_chunking_regex="[^,.;。]+[,.;。]?",
    )
    
    return components

def migrate_query_engine_tools(components, aeroflow_content=None, ecosprint_content=None):
    """
    Migrate your existing query engine tools from Azure to local deployment
    This function recreates your Aeroflow and EcoSprint tools with local models
    """
    from llama_index.core.tools import QueryEngineTool
    from llama_index.core import VectorStoreIndex, Document
    
    # Use provided content or create placeholder documents
    if aeroflow_content is None:
        aeroflow_content = """
        Aeroflow Technical Specifications and Features:
        
        Design Philosophy: Advanced aerodynamic engineering with computational fluid dynamics optimization.
        The Aeroflow system incorporates state-of-the-art materials science and precision manufacturing.
        
        Performance Features:
        - Hybrid-electric propulsion system with 40% improved fuel efficiency
        - Advanced composite materials reducing weight by 25%
        - Integrated sensor arrays for real-time performance monitoring
        - Automated flight path optimization using machine learning algorithms
        
        Technology Integration:
        - Next-generation avionics with touch-screen interfaces
        - Redundant safety systems with triple-backup protocols
        - Weather-adaptive control systems
        - Satellite-based navigation with precision landing capabilities
        
        Maintenance Schedule:
        - Routine inspections every 500 operational hours
        - Major overhaul required at 5,000 hours
        - Component replacement following manufacturer guidelines
        - Digital maintenance logging with predictive analytics
        
        Warranty Coverage:
        - Comprehensive 24-month warranty from delivery
        - Extended warranty options available up to 60 months
        - Global service network with certified technicians
        - 24/7 technical support hotline
        """
    
    if ecosprint_content is None:
        ecosprint_content = """
        EcoSprint Environmental Technology Specifications:
        
        Sustainability Focus: Designed for minimal environmental impact with maximum operational efficiency.
        EcoSprint represents breakthrough innovation in green transportation technology.
        
        Environmental Features:
        - Zero-emission electric drive system with regenerative capabilities
        - Solar panel integration for auxiliary power generation
        - Recyclable materials comprising 80% of total construction
        - Carbon-neutral manufacturing process certification
        
        Advanced Technology:
        - Intelligent battery management with thermal optimization
        - Predictive maintenance using IoT sensors throughout the system
        - Mobile app integration for remote monitoring and control
        - Over-the-air software updates for continuous improvement
        
        Operational Efficiency:
        - Extended range capabilities up to 500km on single charge
        - Fast-charging technology achieving 80% capacity in 30 minutes
        - Adaptive power management based on usage patterns
        - Integration with smart grid systems for optimal charging
        
        Maintenance Requirements:
        - Minimal maintenance design with self-diagnostic capabilities
        - Scheduled inspections every 1,000 operational hours
        - Component health monitoring through integrated sensors
        - Automated maintenance alerts and scheduling
        
        Warranty and Support:
        - Industry-leading 36-month comprehensive warranty
        - Extended service agreements available
        - ISO 14001 environmental compliance certification
        - Remote diagnostic capabilities with expert technical support
        """
    
    # Create documents from content
    aeroflow_docs = [Document(text=aeroflow_content)]
    ecosprint_docs = [Document(text=ecosprint_content)]
    
    print("Creating local indexes for product specifications...")
    
    # Create local indexes with your specified models
    aeroflow_index = VectorStoreIndex.from_documents(
        aeroflow_docs,
        embed_model=components['embed_model'],
        node_parser=components['text_splitter'],
        show_progress=True
    )
    
    ecosprint_index = VectorStoreIndex.from_documents(
        ecosprint_docs,
        embed_model=components['embed_model'], 
        node_parser=components['text_splitter'],
        show_progress=True
    )
    
    # Create query engine tools (exactly like your original code structure)
    aeroflow_tool = QueryEngineTool.from_defaults(
        query_engine=aeroflow_index.as_query_engine(
            llm=components['llm'],
            similarity_top_k=3,
            response_mode="compact"
        ),
        name="Aeroflow specifications",
        description="Contains information about Aeroflow: Design, features, technology, maintenance, warranty"
    )
    
    ecosprint_tool = QueryEngineTool.from_defaults(
        query_engine=ecosprint_index.as_query_engine(
            llm=components['llm'],
            similarity_top_k=3,
            response_mode="compact"
        ),
        name="EcoSprint specifications", 
        description="Contains information about EcoSprint: Design, features, technology, maintenance, warranty"
    )
    
    print("✅ Successfully created local query engine tools!")
    return aeroflow_tool, ecosprint_tool, aeroflow_index, ecosprint_index

def create_local_router_agent(aeroflow_tool, ecosprint_tool, components):
    """
    Create the local equivalent of your RouterQueryEngine
    This replaces your Azure-based router with local models
    """
    from llama_index.core.query_engine.router_query_engine import RouterQueryEngine
    from llama_index.core.selectors import LLMSingleSelector
    
    # Create router agent with local LLM (exactly like your original code)
    router_agent = RouterQueryEngine(
        selector=LLMSingleSelector.from_defaults(llm=components['llm']),
        query_engine_tools=[
            aeroflow_tool,
            ecosprint_tool,
        ],
        verbose=True
    )
    
    print("✅ Local router agent created successfully!")
    return router_agent

# Create components using your successful configuration
print("Creating local RAG components with your working models...")
local_components = create_local_rag_components(
    llm_model="mixtral:8x7b",  # Your successful model
    embedding_model="sentence-transformers/all-MiniLM-L6-v2"  # Your successful model
)

print("✅ Local RAG components created and ready for migration!")
print("\nComponents created:")
print(f"  - LLM: {local_components['llm'].model}")
print(f"  - Embeddings: {local_components['embed_model'].model_name}")
print(f"  - Text Splitter: {local_components['text_splitter'].chunk_size} chars with {local_components['text_splitter'].chunk_overlap} overlap")
# Out:
# === MIGRATION HELPER FUNCTIONS ===
# Creating local RAG components with your working models...
# ✅ Local RAG components created and ready for migration!
#
# Components created:
#   - LLM: mixtral:8x7b
#   - Embeddings: sentence-transformers/all-MiniLM-L6-v2
#   - Text Splitter: 800 chars with 100 overlap

# %% [markdown]
# ## 8: Performance Monitoring and Optimization

# %%
import time
import psutil
import os

print("=== PERFORMANCE MONITORING SETUP ===")

def monitor_system_resources():
    """Monitor system resources during RAG operations"""
    stats = {
        'cpu_percent': psutil.cpu_percent(interval=1),
        'memory_percent': psutil.virtual_memory().percent,
        'memory_used_gb': psutil.virtual_memory().used / (1024**3),
        'memory_total_gb': psutil.virtual_memory().total / (1024**3),
    }
    
    print(f"💻 System Resources:")
    print(f"  CPU Usage: {stats['cpu_percent']:.1f}%")
    print(f"  Memory Usage: {stats['memory_percent']:.1f}% ({stats['memory_used_gb']:.1f}GB / {stats['memory_total_gb']:.1f}GB)")
    
    return stats

def benchmark_rag_operation(query_engine, query, iterations=3):
    """Benchmark RAG query performance"""
    print(f"\n⏱️  Benchmarking Query: '{query}'")
    
    times = []
    for i in range(iterations):
        start_time = time.time()
        response = query_engine.query(query)
        end_time = time.time()
        
        query_time = end_time - start_time
        times.append(query_time)
        print(f"  Iteration {i+1}: {query_time:.2f}s")
    
    avg_time = sum(times) / len(times)
    print(f"  Average time: {avg_time:.2f}s")
    print(f"  Response length: {len(response.response)} characters")
    
    return avg_time, response

# Monitor current system state
initial_stats = monitor_system_resources()

print("\n✅ Ready for local RAG operations!")
print("\nNext steps:")
print("1. Share your Azure OpenAI code for specific migration")
print("2. Test with your actual PDF documents") 
print("3. Optimize chunk sizes and model parameters")
print("4. Plan Docker containerization strategy")
# Out:
# === PERFORMANCE MONITORING SETUP ===
# 💻 System Resources:
#   CPU Usage: 16.6%
#   Memory Usage: 82.1% (46.9GB / 64.0GB)
#
# ✅ Ready for local RAG operations!
#
# Next steps:
# 1. Share your Azure OpenAI code for specific migration
# 2. Test with your actual PDF documents
# 3. Optimize chunk sizes and model parameters
# 4. Plan Docker containerization strategy
